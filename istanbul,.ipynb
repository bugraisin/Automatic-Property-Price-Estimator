# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('istanbul.csv')
data = data.apply(lambda x: x.str.replace(r'0 \(Yeni\)', '0', regex=True) if x.dtype == "object" else x)
data = data.apply(lambda x: x.str.replace(r'Ve Üzeri', '', regex=True) if x.dtype == "object" else x)
sütunlar = [
    'Yapı Durumu', 'Krediye Uygunluk', 'Isıtma Tipi', 
    'Site İçerisinde', 'Kullanım Durumu', 'Yatırıma Uygunluk', 
    'Banyo Sayısı', 'WC Sayısı', 'Eşya Durumu', 'Tapu Durumu', 
    'Balkon Sayısı', 'Tipi', 'Unnamed: 0'
]       
data.drop(columns=sütunlar, inplace=True, errors='ignore')
data
# Out:
#           Fiyat  Oda Sayısı  Bulunduğu Kat  Brüt Metrekare Binanın Yaşı  \
# 0       2950000           3              1              85          21
# 1       9450000           6              2             170          21
# 2       3550000           3              1              85          21
# 3      15300000           6              6             250          21
# 4      13000000           5              2             230          21
# ...         ...         ...            ...             ...          ...
# 25903   3900000           3              1              95            0
# 25904   8000000           7              5             250          21
# 25905   4100000           3              3             100         5-10
# 25906   5000000           7              5             250          21
# 25907   3400000           3              3             130            0
#
#        Binanın Kat Sayısı     Sehir         Ilce               Mahalle
# 0                       4  İstanbul       Adalar  Heybeliada Mahallesi
# 1                       3  İstanbul       Adalar       Maden Mahallesi
# 2                       3  İstanbul       Adalar  Heybeliada Mahallesi
# 3                       6  İstanbul       Adalar   Burgazada Mahallesi
# 4                       3  İstanbul       Adalar  Heybeliada Mahallesi
# ...                   ...       ...          ...                   ...
# 25903                   5  İstanbul  Zeytinburnu  Veliefendi Mahallesi
# 25904                   5  İstanbul  Zeytinburnu   Beştelsiz Mahallesi
# 25905                   5  İstanbul  Zeytinburnu    Nuripaşa Mahallesi
# 25906                   5  İstanbul  Zeytinburnu   Beştelsiz Mahallesi
# 25907                   3  İstanbul  Zeytinburnu   Beştelsiz Mahallesi
#
# [25908 rows x 9 columns]

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

categorical_cols = ['Sehir', 'Ilce', 'Mahalle']
column_transformer = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(), categorical_cols),
        ('scaler', StandardScaler(), numerical_cols)
    ],
    remainder='passthrough'  # Diğer sütunları olduğu gibi bırak
)
X_transformed = column_transformer.fit_transform(data)
data.head
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 8
#       2 from sklearn.compose import ColumnTransformer
#       4 categorical_cols = ['Sehir', 'Ilce', 'Mahalle']
#       5 column_transformer = ColumnTransformer(
#       6     transformers=[
#       7         ('onehot', OneHotEncoder(), categorical_cols),
# ----> 8         ('scaler', StandardScaler(), numerical_cols)
#       9     ],
#      10     remainder='passthrough'  # Diğer sütunları olduğu gibi bırak
#      11 )
#      12 X_transformed = column_transformer.fit_transform(data)
#      13 data.head
#
# NameError: name 'numerical_cols' is not defined
